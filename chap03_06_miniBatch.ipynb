# %% [markdown]
# <a href="https://colab.research.google.com/github/DeuklyoungKo/toStartDeepLearningWithPyTorch/blob/main/chap03_06_miniBatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
x_train = torch.FloatTensor([[73,  80,  75], 
                             [93,  88,  93], 
                             [89,  91,  90], 
                             [96,  98,  100],   
                             [73,  66,  70]])
y_train = torch.FloatTensor([[152],[185],[180],[196],[142]])

# %%
dataset = TensorDataset(x_train, y_train)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 200
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    x_train, y_train = samples
    prediction = model(x_train)

    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} cost: {:6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
    ))
# Out:
# Epoch    0/200 Batch 1/3 cost: 17.277805
# Epoch    0/200 Batch 2/3 cost: 11.042398
# Epoch    0/200 Batch 3/3 cost: 0.147833
# Epoch    1/200 Batch 1/3 cost: 10.671019
# Epoch    1/200 Batch 2/3 cost: 6.491966
# Epoch    1/200 Batch 3/3 cost: 5.220057
# Epoch    2/200 Batch 1/3 cost: 0.735235
# Epoch    2/200 Batch 2/3 cost: 10.824378
# Epoch    2/200 Batch 3/3 cost: 14.672654
# Epoch    3/200 Batch 1/3 cost: 14.223948
# Epoch    3/200 Batch 2/3 cost: 6.099435
# Epoch    3/200 Batch 3/3 cost: 8.349804
# Epoch    4/200 Batch 1/3 cost: 17.487194
# Epoch    4/200 Batch 2/3 cost: 10.813382
# Epoch    4/200 Batch 3/3 cost: 3.206862
# Epoch    5/200 Batch 1/3 cost: 6.242844
# Epoch    5/200 Batch 2/3 cost: 4.289749
# Epoch    5/200 Batch 3/3 cost: 16.025156
# Epoch    6/200 Batch 1/3 cost: 7.787281
# Epoch    6/200 Batch 2/3 cost: 10.788067
# Epoch    6/200 Batch 3/3 cost: 0.064530
# Epoch    7/200 Batch 1/3 cost: 6.070926
# Epoch    7/200 Batch 2/3 cost: 18.451418
# ...

# %%
new_var = torch.FloatTensor([[73,80,75]])
pred_y = model(new_var)
print('훈련 후 입력이 73,80,75 일 때의 예측값 : ', pred_y)
# Out:
# 훈련 후 입력이 73,80,75 일 때의 예측값 :  tensor([[155.5916]], grad_fn=<AddmmBackward0>)
